# %%
from importlib import reload
import command_file

# %%
def print_recur (subdict: dict, indent = 0, key_len_max = 0):
    
    __ichar = '\t'
    __iincr = 1
    def __serialize (x):
        if type(x) == bool:
            return 'YES' if x else 'NO'
        return x

    # Run through subdict's items
    for key, val in subdict.items():

        # Subdicts
        if type(val) == dict:
            
            # Only one leaf (non-iterable value): compact writing (curly brackets on the same line)
            subitems = list(val.values())
            if len(subitems) == 1 and type(subitems[0]) in (str, int, float, bool, type(None)):
                print_prefix = f'{__serialize(key)} '
                print_suffix = f'= {{ {__serialize(list(val.keys())[0])} }}'
                if key_len_max > len(print_prefix): print_prefix += ' ' * (key_len_max - len(print_prefix))
                print(__ichar*indent + print_prefix + print_suffix)  # Print
            
            # Multiple subitems: expanded dict writing (recursive call) - no formatting adjustment with spaces
            else:
                # Calculate key_len_max (ignore keys of expanded dicts and special keys)
                keys_eligible_ = list()
                for key_, val_ in val.items():
                    # Special keys
                    if key_ == '__inline__': continue
                    # Non-iterable values
                    if type(val_) in (str, int, float, bool, type(None)):
                        keys_eligible_.append(key_)
                    # Single-element dict values
                    elif type(val_) == dict:
                        subitems = list(val_.values())
                        if len(subitems) == 1 and type(subitems[0]) in (str, int, float, type(None)):
                            keys_eligible_.append(key_)
                key_len_max_ = max([len(key) for key in keys_eligible_]) + 1 if keys_eligible_ else 0

                print(__ichar*indent + f'{__serialize(key)} = {{')
                print_recur(val, indent=indent+__iincr, key_len_max=key_len_max_)
                print(__ichar*indent + '}')


        # Unpack lists to assign the key to each subdictionary
        elif type(val) == list:
            for item in val:
                print_recur({key: item}, indent=indent)  # Distribute print_recur across all subdicts contained in the list


        # End node (leaf)
        else:

            # Inline text (prints value only, formatted as "value") for elements of dict with '__inline__' key
            if key == '__inline__':
                print(__ichar*indent + __serialize(val))

            # TODO: Deprecated
            # # Inline text (prints key only, formatted as "key") for elements of dict with value of None
            # elif val is None:  # For an element of a dict which is 'x': None, will only print 'x' with indent
            #     print(__ichar*indent + __serialize(key))

            # Regular key-pair formatted as "key = value"
            else:
                print_prefix = f'{__serialize(key)} '
                print_suffix = f'= {__serialize(val)}'
                if key_len_max > len(print_prefix): print_prefix += ' ' * (key_len_max - len(print_prefix))
                print(__ichar*indent + print_prefix + print_suffix )  # TODO: format number of spaces for alignment

# %%
reload(command_file)
print_recur(command_file.MY_DICT)
# Out:
# Output_folder = /data/DATA/DATA_CAWAQS_OUT/TestProj
# simulation = {
# 	SEINE_SIMPLE
# 	TIME = {
# 		year_init = 2000
# 		year_end  = 2010
# 		dt        = [d] 1.
# 	}
# 	SETTINGS = {
# 		transport   = NO
# 		type        = transient
# 		eps_Q       = [m3/s] 0.000001
# 		eps_Z       = [m] 0.00001
# 		theta       = 1.0
# 		nit_pic_max = 1
# 		eps_pic     = [cm] 15
# 		print_surf  = YES
# 		debug       = NO
# 	}
# }
# HYDRO = {
# 	AQUIFER = {
# 		SETTINGS = {
# 			anisotropy_factor = 0.1
# 			log_fluxes        = NO
# 			print_lithos      = NO
# 		}
# 		OMP = { NO nthreads }
# 		GW_MESH = {
# 			layer = { tertiaire   include grid_TERT.txt }
# 			layer = { craie       include grid_CRAI.txt }
# 			layer = { jurassique  include grid_JURA.txt }
# 		}
# 		SET_UP = {
# 			setup_layer = {
# 				tertiaire
# 				param = {
# 					transm_homo = { include Transm_HET_TERT.txt }
# 					storage     = { include Emmag_HET_TERT.txt }
# 					h_ini       = { include H_ini_HET_TERT.txt }
# 					thick       = { include Thickness_HET_TERT.txt }
# 					conductance = { include Cond_TOP_noRIV_TERT.txt }
# 					Mean        = HARMONIC
# 				}
# 				boundary = { include Bound_TERT.txt }
# 			}
# 			setup_layer = {
# 				craie
# 				param = {
# 					transm_homo = { include Transm_HET_CRAI.txt }
# 					storage     = { include Emmag_HET_CRAI.txt }
# 					h_ini       = { include H_ini_HET_CRAI.txt }
# 					thick       = { include Thickness_HET_CRAI.txt }
# 					conductance = { include Cond_TOP_noRIV_CRAI.txt }
# 					Mean        = HARMONIC
# 				}
# 				boundary = { include Bound_CRAI.txt }
# 			}
# 			setup_layer = {
# 				jurassique
# 				param = {
# 					transm_homo = { include Transm_HET_JURA.txt }
# 					storage     = { include Emmag_HET_JURA.txt }
# 					h_ini       = { include H_ini_HET_JURA.txt }
# 					thick       = { include Thickness_HET_JURA.txt }
# 					conductance = { include Cond_TOP_noRIV_JURA.txt }
# 					Mean        = HARMONIC
# 				}
# 				boundary = { include Bound_JURA.txt }
# 			}
# 		}
# 	}
# 	SURFACE = {
# 		MTO = {
# 			mto_path    = /home/anatole/Documents/DATA_CAWAQS/SEINE_3C/DATA_SEINE_SIMPLE/METEO
# 			rain_prefix = precip
# 			etp_prefix  = etp
# 			format      = UNFORMATTED
# 			mto_cell    = { include MTO_CELLS.txt }
# 		}
# 		WATER_BALANCE_UNIT = {
# 			OMP         = { YES nthreads }
# 			param       = { include DONSUR_BU28.txt }
# 			BU          = { include LIEN_BU28_MTO.txt }
# 			Cprod       = { include LIEN_ELE_BU_CPROD.txt }
# 			Cprod_no_aq = { include LIEN_CPROD_BU_NO_AQ.txt }
# 			Cprod_aq    = { include LIEN_CPROD_AQ.txt }
# 		}
# 		NETWORK_DESCRIPTION = {
# 			settings = {
# 				ndim                = 1
# 				calculate_curvature = NO
# 				dx                  = [m] 0
# 				dz                  = [m] 10
# 				upstream_Hmin       = [m] 0.
# 				downstream_Hmax     = [m] 10.
# 				schem_type          = MUSKINGUM
# 				K_DEF               = TTRA
# 			}
# 			OMP           = { NO nthreads }
# 			network_musk  = { include NETWORK_MUSK.txt }
# 			elements_musk = { include ELEMENTS_MUSK.txt }
# 		}
# 	}
# 	NONSAT = {
# 		OMP        = { NO nthreads }
# 		param      = { include PARAM_NSAT.txt }
# 		nsat_units = { include LIEN_NSAT_PARAM.txt }
# 		nsat_prod  = { include LIEN_NSAT_ELE_BU.txt }
# 		nsat_aq    = { include LIEN_NSAT_AQF.txt }
# 	}
# }
# OUTPUTS = {
# 	MB_AQ = {
# 		Output_settings = {
# 			NO
# 			format            = UNFORMATTED
# 			print_final_state = YES
# 			time              = { dt = [d] 1 }
# 		}
# 	}
# 	H_AQ = {
# 		Output_settings = {
# 			YES
# 			format            = UNFORMATTED
# 			print_final_state = NO
# 			time              = { dt = [d] 1 }
# 		}
# 	}
# 	Q_HYD = {
# 		Output_settings = {
# 			YES
# 			format            = UNFORMATTED
# 			print_final_state = NO
# 			time              = { dt = [d] 1 }
# 		}
# 	}
# 	NSAT = {
# 		Output_settings = {
# 			NO
# 			format = UNFORMATTED
# 			time   = { dt = [d] 1 }
# 		}
# 	}
# 	WATBAL = {
# 		Output_settings = {
# 			YES
# 			format        = UNFORMATTED
# 			time          = { dt = [d] 1 }
# 			spatial_scale = WATBAL_ELEMENT
# 		}
# 	}
# }

# %%
{None:''}
# Out:
# {None: ''}

# %%
type(None)
# Out:
# NoneType
